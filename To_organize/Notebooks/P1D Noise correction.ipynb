# %% [markdown]
# # Libraries

# %%
import os
import sys
import glob
import numpy as np
import scipy.optimize    as op
import matplotlib.pyplot as plt
import urllib.request
from astropy.io import fits
from astropy.table import Table
from scipy.interpolate import make_interp_spline
import fitsio

# %% [markdown]
# # List of files to be modified

# %%
folder = "/home/colgoat/PSChab/run5_n"
list_raw = os.listdir(folder)
list_raw.sort()
name_list = np.array(list_raw)
ff = np.char.find(name_list, ("Pk1D-" and ".fits"), start=0, end=None) ## ff = Names' flaws finder
for i in range(len(list_raw)):
    if (ff[i]==(-1)):
        name_list = np.delete(name_list,i)
print(name_list, len(name_list))
# Out:
# ['Pk1D-0_A.fits.gz' 'Pk1D-0_B.fits.gz' 'Pk1D-0_C.fits.gz'
#  'Pk1D-10_A.fits.gz' 'Pk1D-10_B.fits.gz' 'Pk1D-10_C.fits.gz'
#  'Pk1D-11_A.fits.gz' 'Pk1D-11_B.fits.gz' 'Pk1D-11_C.fits.gz'
#  'Pk1D-12_A.fits.gz' 'Pk1D-12_B.fits.gz' 'Pk1D-12_C.fits.gz'
#  'Pk1D-13_A.fits.gz' 'Pk1D-13_B.fits.gz' 'Pk1D-13_C.fits.gz'
#  'Pk1D-14_A.fits.gz' 'Pk1D-14_B.fits.gz' 'Pk1D-14_C.fits.gz'
#  'Pk1D-15_A.fits.gz' 'Pk1D-15_B.fits.gz' 'Pk1D-15_C.fits.gz'
#  'Pk1D-16_A.fits.gz' 'Pk1D-16_B.fits.gz' 'Pk1D-16_C.fits.gz'
#  'Pk1D-17_A.fits.gz' 'Pk1D-17_B.fits.gz' 'Pk1D-17_C.fits.gz'
#  'Pk1D-18_A.fits.gz' 'Pk1D-18_B.fits.gz' 'Pk1D-18_C.fits.gz'
#  'Pk1D-19_A.fits.gz' 'Pk1D-19_B.fits.gz' 'Pk1D-19_C.fits.gz'
#  'Pk1D-1_A.fits.gz' 'Pk1D-1_B.fits.gz' 'Pk1D-1_C.fits.gz'
#  'Pk1D-20_A.fits.gz' 'Pk1D-20_B.fits.gz' 'Pk1D-20_C.fits.gz'
#  'Pk1D-21_A.fits.gz' 'Pk1D-21_B.fits.gz' 'Pk1D-21_C.fits.gz'
#  'Pk1D-22_A.fits.gz' 'Pk1D-22_B.fits.gz' 'Pk1D-22_C.fits.gz'
#  'Pk1D-23_A.fits.gz' 'Pk1D-23_B.fits.gz' 'Pk1D-23_C.fits.gz'
#  'Pk1D-24_A.fits.gz' 'Pk1D-24_B.fits.gz' 'Pk1D-24_C.fits.gz'
#  'Pk1D-25_A.fits.gz' 'Pk1D-25_B.fits.gz' 'Pk1D-25_C.fits.gz'
#  'Pk1D-26_A.fits.gz' 'Pk1D-26_B.fits.gz' 'Pk1D-26_C.fits.gz'
#  'Pk1D-27_A.fits.gz' 'Pk1D-27_B.fits.gz' 'Pk1D-27_C.fits.gz'
#  'Pk1D-28_A.fits.gz' 'Pk1D-28_B.fits.gz' 'Pk1D-28_C.fits.gz'
#  'Pk1D-29_A.fits.gz' 'Pk1D-29_B.fits.gz' 'Pk1D-29_C.fits.gz'
#  'Pk1D-2_A.fits.gz' 'Pk1D-2_B.fits.gz' 'Pk1D-2_C.fits.gz'
#  'Pk1D-30_A.fits.gz' 'Pk1D-30_B.fits.gz' 'Pk1D-30_C.fits.gz'
#  'Pk1D-31_A.fits.gz' 'Pk1D-31_B.fits.gz' 'Pk1D-31_C.fits.gz'
#  'Pk1D-32_A.fits.gz' 'Pk1D-32_B.fits.gz' 'Pk1D-32_C.fits.gz'
#  'Pk1D-33_A.fits.gz' 'Pk1D-33_B.fits.gz' 'Pk1D-33_C.fits.gz'
#  'Pk1D-34_A.fits.gz' 'Pk1D-34_B.fits.gz' 'Pk1D-34_C.fits.gz'
#  'Pk1D-35_A.fits.gz' 'Pk1D-35_B.fits.gz' 'Pk1D-35_C.fits.gz'
#  'Pk1D-36_A.fits.gz' 'Pk1D-36_B.fits.gz' 'Pk1D-36_C.fits.gz'
#  'Pk1D-37_A.fits.gz' 'Pk1D-37_B.fits.gz' 'Pk1D-37_C.fits.gz'
#  'Pk1D-38_A.fits.gz' 'Pk1D-38_B.fits.gz' 'Pk1D-38_C.fits.gz'
#  'Pk1D-39_A.fits.gz' 'Pk1D-39_B.fits.gz' 'Pk1D-39_C.fits.gz'
#  'Pk1D-3_A.fits.gz' 'Pk1D-3_B.fits.gz' 'Pk1D-3_C.fits.gz'
#  'Pk1D-40_A.fits.gz' 'Pk1D-40_B.fits.gz' 'Pk1D-40_C.fits.gz'
#  'Pk1D-41_A.fits.gz' 'Pk1D-41_B.fits.gz' 'Pk1D-41_C.fits.gz'
#  'Pk1D-42_A.fits.gz' 'Pk1D-42_B.fits.gz' 'Pk1D-42_C.fits.gz'
#  'Pk1D-43_A.fits.gz' 'Pk1D-43_B.fits.gz' 'Pk1D-43_C.fits.gz'
#  'Pk1D-44_A.fits.gz' 'Pk1D-44_B.fits.gz' 'Pk1D-44_C.fits.gz'
#  'Pk1D-45_A.fits.gz' 'Pk1D-45_B.fits.gz' 'Pk1D-45_C.fits.gz'
#  'Pk1D-46_A.fits.gz' 'Pk1D-46_B.fits.gz' 'Pk1D-46_C.fits.gz'
#  'Pk1D-47_A.fits.gz' 'Pk1D-47_B.fits.gz' 'Pk1D-47_C.fits.gz'
#  'Pk1D-48_A.fits.gz' 'Pk1D-48_B.fits.gz' 'Pk1D-48_C.fits.gz'
#  'Pk1D-49_A.fits.gz' 'Pk1D-49_B.fits.gz' 'Pk1D-49_C.fits.gz'
#  'Pk1D-4_A.fits.gz' 'Pk1D-4_B.fits.gz' 'Pk1D-4_C.fits.gz'
#  'Pk1D-50_A.fits.gz' 'Pk1D-50_B.fits.gz' 'Pk1D-50_C.fits.gz'
#  'Pk1D-51_A.fits.gz' 'Pk1D-51_B.fits.gz' 'Pk1D-51_C.fits.gz'
#  'Pk1D-52_A.fits.gz' 'Pk1D-52_B.fits.gz' 'Pk1D-52_C.fits.gz'
#  'Pk1D-53_A.fits.gz' 'Pk1D-53_B.fits.gz' 'Pk1D-53_C.fits.gz'
#  'Pk1D-54_A.fits.gz' 'Pk1D-54_B.fits.gz' 'Pk1D-54_C.fits.gz'
#  'Pk1D-55_A.fits.gz' 'Pk1D-55_B.fits.gz' 'Pk1D-55_C.fits.gz'
#  'Pk1D-56_A.fits.gz' 'Pk1D-56_B.fits.gz' 'Pk1D-56_C.fits.gz'
#  'Pk1D-57_A.fits.gz' 'Pk1D-57_B.fits.gz' 'Pk1D-57_C.fits.gz'
#  'Pk1D-58_A.fits.gz' 'Pk1D-58_B.fits.gz' 'Pk1D-58_C.fits.gz'
#  'Pk1D-59_A.fits.gz' 'Pk1D-59_B.fits.gz' 'Pk1D-59_C.fits.gz'
#  'Pk1D-5_A.fits.gz' 'Pk1D-5_B.fits.gz' 'Pk1D-5_C.fits.gz'
#  'Pk1D-60_A.fits.gz' 'Pk1D-60_B.fits.gz' 'Pk1D-60_C.fits.gz'
#  'Pk1D-61_A.fits.gz' 'Pk1D-61_B.fits.gz' 'Pk1D-61_C.fits.gz'
#  'Pk1D-62_A.fits.gz' 'Pk1D-62_B.fits.gz' 'Pk1D-62_C.fits.gz'
#  'Pk1D-63_A.fits.gz' 'Pk1D-63_B.fits.gz' 'Pk1D-63_C.fits.gz'
#  'Pk1D-64_A.fits.gz' 'Pk1D-64_B.fits.gz' 'Pk1D-64_C.fits.gz'
#  'Pk1D-65_A.fits.gz' 'Pk1D-65_B.fits.gz' 'Pk1D-65_C.fits.gz'
#  'Pk1D-66_A.fits.gz' 'Pk1D-66_B.fits.gz' 'Pk1D-66_C.fits.gz'
#  'Pk1D-67_A.fits.gz' 'Pk1D-67_B.fits.gz' 'Pk1D-67_C.fits.gz'
#  'Pk1D-68_A.fits.gz' 'Pk1D-68_B.fits.gz' 'Pk1D-68_C.fits.gz'
#  'Pk1D-69_A.fits.gz' 'Pk1D-69_B.fits.gz' 'Pk1D-69_C.fits.gz'
#  'Pk1D-6_A.fits.gz' 'Pk1D-6_B.fits.gz' 'Pk1D-6_C.fits.gz'
#  'Pk1D-70_A.fits.gz' 'Pk1D-70_B.fits.gz' 'Pk1D-70_C.fits.gz'
#  'Pk1D-71_A.fits.gz' 'Pk1D-71_B.fits.gz' 'Pk1D-71_C.fits.gz'
#  'Pk1D-72_A.fits.gz' 'Pk1D-72_B.fits.gz' 'Pk1D-72_C.fits.gz'
#  'Pk1D-73_A.fits.gz' 'Pk1D-73_B.fits.gz' 'Pk1D-73_C.fits.gz'
#  'Pk1D-74_B.fits.gz' 'Pk1D-74_C.fits.gz' 'Pk1D-7_A.fits.gz'
#  'Pk1D-7_B.fits.gz' 'Pk1D-7_C.fits.gz' 'Pk1D-8_A.fits.gz'
#  'Pk1D-8_B.fits.gz' 'Pk1D-8_C.fits.gz' 'Pk1D-9_A.fits.gz'
#  'Pk1D-9_B.fits.gz' 'Pk1D-9_C.fits.gz'] 224

# %%
def noise_calc_fits(folder,file,c1,c2): # Function to modify the Pk1D- files
    path = os.path.join(folder,str(file)) # Path to a given file
    fits_file = fits.open(path) # Open .fits file to retrieve HDUs 
    
    with fits.open(path, mode='update') as hdus:
        for i in range(len(fits_file)): # Loop for number of HDUs in the P1D file
            if (i>0):
                mean_z = fits_file[i].header['MEANZ'] # Retrieving the MEANZ value for this chunk
                if (mean_z <= 2.7): # Considering only the first three redshift bins
                    T = Table.read(hdus[i])
                    T['PK_DIFF'] = T["PK_DIFF"]*0.95 # Applying Beta correction
                    up_hdu = fits.BinTableHDU(data = T, header = fits_file[i].header) #updated BinTableHDU
                    hdus[i] = up_hdu # Adding to the original HDU
                else:
                    pass
            else:
                pass
        hdus.flush() # Saving the update
    print(f"{str(file)} noise correction updated : file {c1}/{c2}")

# %%
def p1d_noise_set(folder, name_list):
    n_f =  len(name_list) #n_f = Number of files on folder
    for b in range(n_f):
        noise_calc_fits(folder,name_list[b],b+1,n_f) # Applying the correction for all files
    print(f"Done for all files({n_f})")

# %%
p1d_noise_set(folder,name_list)
# Out:
# WARNING: UnitsWarning: '(km/s)^-1' did not parse as fits unit: Syntax error parsing unit '(km/s)^-1' If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: VerifyWarning: Keyword name 'NBMASKPIX' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# Pk1D-0_A.fits noise correction updated : file 1/224
# Pk1D-0_B.fits noise correction updated : file 2/224
# Pk1D-0_C.fits noise correction updated : file 3/224
# Pk1D-10_A.fits noise correction updated : file 4/224
# Pk1D-10_B.fits noise correction updated : file 5/224
# Pk1D-10_C.fits noise correction updated : file 6/224
# Pk1D-11_A.fits noise correction updated : file 7/224
# Pk1D-11_B.fits noise correction updated : file 8/224
# Pk1D-11_C.fits noise correction updated : file 9/224
# Pk1D-12_A.fits noise correction updated : file 10/224
# Pk1D-12_B.fits noise correction updated : file 11/224
# Pk1D-12_C.fits noise correction updated : file 12/224
# Pk1D-13_A.fits noise correction updated : file 13/224
# Pk1D-13_B.fits noise correction updated : file 14/224
# Pk1D-13_C.fits noise correction updated : file 15/224
# Pk1D-14_A.fits noise correction updated : file 16/224
# Pk1D-14_B.fits noise correction updated : file 17/224
# Pk1D-14_C.fits noise correction updated : file 18/224
# Pk1D-15_A.fits noise correction updated : file 19/224
# Pk1D-15_B.fits noise correction updated : file 20/224
# Pk1D-15_C.fits noise correction updated : file 21/224
# Pk1D-16_A.fits noise correction updated : file 22/224
# Pk1D-16_B.fits noise correction updated : file 23/224
# Pk1D-16_C.fits noise correction updated : file 24/224
# Pk1D-17_A.fits noise correction updated : file 25/224
# Pk1D-17_B.fits noise correction updated : file 26/224
# Pk1D-17_C.fits noise correction updated : file 27/224
# Pk1D-18_A.fits noise correction updated : file 28/224
# Pk1D-18_B.fits noise correction updated : file 29/224
# Pk1D-18_C.fits noise correction updated : file 30/224
# Pk1D-19_A.fits noise correction updated : file 31/224
# Pk1D-19_B.fits noise correction updated : file 32/224
# Pk1D-19_C.fits noise correction updated : file 33/224
# Pk1D-1_A.fits noise correction updated : file 34/224
# Pk1D-1_B.fits noise correction updated : file 35/224
# Pk1D-1_C.fits noise correction updated : file 36/224
# Pk1D-20_A.fits noise correction updated : file 37/224
# Pk1D-20_B.fits noise correction updated : file 38/224
# Pk1D-20_C.fits noise correction updated : file 39/224
# Pk1D-21_A.fits noise correction updated : file 40/224
# Pk1D-21_B.fits noise correction updated : file 41/224
# Pk1D-21_C.fits noise correction updated : file 42/224
# Pk1D-22_A.fits noise correction updated : file 43/224
# Pk1D-22_B.fits noise correction updated : file 44/224
# Pk1D-22_C.fits noise correction updated : file 45/224
# Pk1D-23_A.fits noise correction updated : file 46/224
# Pk1D-23_B.fits noise correction updated : file 47/224
# Pk1D-23_C.fits noise correction updated : file 48/224
# Pk1D-24_A.fits noise correction updated : file 49/224
# Pk1D-24_B.fits noise correction updated : file 50/224
# Pk1D-24_C.fits noise correction updated : file 51/224
# Pk1D-25_A.fits noise correction updated : file 52/224
# Pk1D-25_B.fits noise correction updated : file 53/224
# Pk1D-25_C.fits noise correction updated : file 54/224
# Pk1D-26_A.fits noise correction updated : file 55/224
# Pk1D-26_B.fits noise correction updated : file 56/224
# Pk1D-26_C.fits noise correction updated : file 57/224
# Pk1D-27_A.fits noise correction updated : file 58/224
# Pk1D-27_B.fits noise correction updated : file 59/224
# Pk1D-27_C.fits noise correction updated : file 60/224
# Pk1D-28_A.fits noise correction updated : file 61/224
# Pk1D-28_B.fits noise correction updated : file 62/224
# Pk1D-28_C.fits noise correction updated : file 63/224
# Pk1D-29_A.fits noise correction updated : file 64/224
# Pk1D-29_B.fits noise correction updated : file 65/224
# Pk1D-29_C.fits noise correction updated : file 66/224
# Pk1D-2_A.fits noise correction updated : file 67/224
# Pk1D-2_B.fits noise correction updated : file 68/224
# Pk1D-2_C.fits noise correction updated : file 69/224
# Pk1D-30_A.fits noise correction updated : file 70/224
# Pk1D-30_B.fits noise correction updated : file 71/224
# Pk1D-30_C.fits noise correction updated : file 72/224
# Pk1D-31_A.fits noise correction updated : file 73/224
# Pk1D-31_B.fits noise correction updated : file 74/224
# Pk1D-31_C.fits noise correction updated : file 75/224
# Pk1D-32_A.fits noise correction updated : file 76/224
# Pk1D-32_B.fits noise correction updated : file 77/224
# Pk1D-32_C.fits noise correction updated : file 78/224
# Pk1D-33_A.fits noise correction updated : file 79/224
# Pk1D-33_B.fits noise correction updated : file 80/224
# Pk1D-33_C.fits noise correction updated : file 81/224
# Pk1D-34_A.fits noise correction updated : file 82/224
# Pk1D-34_B.fits noise correction updated : file 83/224
# Pk1D-34_C.fits noise correction updated : file 84/224
# Pk1D-35_A.fits noise correction updated : file 85/224
# Pk1D-35_B.fits noise correction updated : file 86/224
# Pk1D-35_C.fits noise correction updated : file 87/224
# Pk1D-36_A.fits noise correction updated : file 88/224
# Pk1D-36_B.fits noise correction updated : file 89/224
# Pk1D-36_C.fits noise correction updated : file 90/224
# Pk1D-37_A.fits noise correction updated : file 91/224
# Pk1D-37_B.fits noise correction updated : file 92/224
# Pk1D-37_C.fits noise correction updated : file 93/224
# Pk1D-38_A.fits noise correction updated : file 94/224
# Pk1D-38_B.fits noise correction updated : file 95/224
# Pk1D-38_C.fits noise correction updated : file 96/224
# Pk1D-39_A.fits noise correction updated : file 97/224
# Pk1D-39_B.fits noise correction updated : file 98/224
# Pk1D-39_C.fits noise correction updated : file 99/224
# Pk1D-3_A.fits noise correction updated : file 100/224
# Pk1D-3_B.fits noise correction updated : file 101/224
# Pk1D-3_C.fits noise correction updated : file 102/224
# Pk1D-40_A.fits noise correction updated : file 103/224
# Pk1D-40_B.fits noise correction updated : file 104/224
# Pk1D-40_C.fits noise correction updated : file 105/224
# Pk1D-41_A.fits noise correction updated : file 106/224
# Pk1D-41_B.fits noise correction updated : file 107/224
# Pk1D-41_C.fits noise correction updated : file 108/224
# Pk1D-42_A.fits noise correction updated : file 109/224
# Pk1D-42_B.fits noise correction updated : file 110/224
# Pk1D-42_C.fits noise correction updated : file 111/224
# Pk1D-43_A.fits noise correction updated : file 112/224
# Pk1D-43_B.fits noise correction updated : file 113/224
# Pk1D-43_C.fits noise correction updated : file 114/224
# Pk1D-44_A.fits noise correction updated : file 115/224
# Pk1D-44_B.fits noise correction updated : file 116/224
# Pk1D-44_C.fits noise correction updated : file 117/224
# Pk1D-45_A.fits noise correction updated : file 118/224
# Pk1D-45_B.fits noise correction updated : file 119/224
# Pk1D-45_C.fits noise correction updated : file 120/224
# Pk1D-46_A.fits noise correction updated : file 121/224
# Pk1D-46_B.fits noise correction updated : file 122/224
# Pk1D-46_C.fits noise correction updated : file 123/224
# Pk1D-47_A.fits noise correction updated : file 124/224
# Pk1D-47_B.fits noise correction updated : file 125/224
# Pk1D-47_C.fits noise correction updated : file 126/224
# Pk1D-48_A.fits noise correction updated : file 127/224
# Pk1D-48_B.fits noise correction updated : file 128/224
# Pk1D-48_C.fits noise correction updated : file 129/224
# Pk1D-49_A.fits noise correction updated : file 130/224
# Pk1D-49_B.fits noise correction updated : file 131/224
# Pk1D-49_C.fits noise correction updated : file 132/224
# Pk1D-4_A.fits noise correction updated : file 133/224
# Pk1D-4_B.fits noise correction updated : file 134/224
# Pk1D-4_C.fits noise correction updated : file 135/224
# Pk1D-50_A.fits noise correction updated : file 136/224
# Pk1D-50_B.fits noise correction updated : file 137/224
# Pk1D-50_C.fits noise correction updated : file 138/224
# Pk1D-51_A.fits noise correction updated : file 139/224
# Pk1D-51_B.fits noise correction updated : file 140/224
# Pk1D-51_C.fits noise correction updated : file 141/224
# Pk1D-52_A.fits noise correction updated : file 142/224
# Pk1D-52_B.fits noise correction updated : file 143/224
# Pk1D-52_C.fits noise correction updated : file 144/224
# Pk1D-53_A.fits noise correction updated : file 145/224
# Pk1D-53_B.fits noise correction updated : file 146/224
# Pk1D-53_C.fits noise correction updated : file 147/224
# Pk1D-54_A.fits noise correction updated : file 148/224
# Pk1D-54_B.fits noise correction updated : file 149/224
# Pk1D-54_C.fits noise correction updated : file 150/224
# Pk1D-55_A.fits noise correction updated : file 151/224
# Pk1D-55_B.fits noise correction updated : file 152/224
# Pk1D-55_C.fits noise correction updated : file 153/224
# Pk1D-56_A.fits noise correction updated : file 154/224
# Pk1D-56_B.fits noise correction updated : file 155/224
# Pk1D-56_C.fits noise correction updated : file 156/224
# Pk1D-57_A.fits noise correction updated : file 157/224
# Pk1D-57_B.fits noise correction updated : file 158/224
# Pk1D-57_C.fits noise correction updated : file 159/224
# Pk1D-58_A.fits noise correction updated : file 160/224
# Pk1D-58_B.fits noise correction updated : file 161/224
# Pk1D-58_C.fits noise correction updated : file 162/224
# Pk1D-59_A.fits noise correction updated : file 163/224
# Pk1D-59_B.fits noise correction updated : file 164/224
# Pk1D-59_C.fits noise correction updated : file 165/224
# Pk1D-5_A.fits noise correction updated : file 166/224
# Pk1D-5_B.fits noise correction updated : file 167/224
# Pk1D-5_C.fits noise correction updated : file 168/224
# Pk1D-60_A.fits noise correction updated : file 169/224
# Pk1D-60_B.fits noise correction updated : file 170/224
# Pk1D-60_C.fits noise correction updated : file 171/224
# Pk1D-61_A.fits noise correction updated : file 172/224
# Pk1D-61_B.fits noise correction updated : file 173/224
# Pk1D-61_C.fits noise correction updated : file 174/224
# Pk1D-62_A.fits noise correction updated : file 175/224
# Pk1D-62_B.fits noise correction updated : file 176/224
# Pk1D-62_C.fits noise correction updated : file 177/224
# Pk1D-63_A.fits noise correction updated : file 178/224
# Pk1D-63_B.fits noise correction updated : file 179/224
# Pk1D-63_C.fits noise correction updated : file 180/224
# Pk1D-64_A.fits noise correction updated : file 181/224
# Pk1D-64_B.fits noise correction updated : file 182/224
# Pk1D-64_C.fits noise correction updated : file 183/224
# Pk1D-65_A.fits noise correction updated : file 184/224
# Pk1D-65_B.fits noise correction updated : file 185/224
# Pk1D-65_C.fits noise correction updated : file 186/224
# Pk1D-66_A.fits noise correction updated : file 187/224
# Pk1D-66_B.fits noise correction updated : file 188/224
# Pk1D-66_C.fits noise correction updated : file 189/224
# Pk1D-67_A.fits noise correction updated : file 190/224
# Pk1D-67_B.fits noise correction updated : file 191/224
# Pk1D-67_C.fits noise correction updated : file 192/224
# Pk1D-68_A.fits noise correction updated : file 193/224
# Pk1D-68_B.fits noise correction updated : file 194/224
# Pk1D-68_C.fits noise correction updated : file 195/224
# Pk1D-69_A.fits noise correction updated : file 196/224
# Pk1D-69_B.fits noise correction updated : file 197/224
# Pk1D-69_C.fits noise correction updated : file 198/224
# Pk1D-6_A.fits noise correction updated : file 199/224
# Pk1D-6_B.fits noise correction updated : file 200/224
# Pk1D-6_C.fits noise correction updated : file 201/224
# Pk1D-70_A.fits noise correction updated : file 202/224
# Pk1D-70_B.fits noise correction updated : file 203/224
# Pk1D-70_C.fits noise correction updated : file 204/224
# Pk1D-71_A.fits noise correction updated : file 205/224
# Pk1D-71_B.fits noise correction updated : file 206/224
# Pk1D-71_C.fits noise correction updated : file 207/224
# Pk1D-72_A.fits noise correction updated : file 208/224
# Pk1D-72_B.fits noise correction updated : file 209/224
# Pk1D-72_C.fits noise correction updated : file 210/224
# Pk1D-73_A.fits noise correction updated : file 211/224
# Pk1D-73_B.fits noise correction updated : file 212/224
# Pk1D-73_C.fits noise correction updated : file 213/224
# Pk1D-74_B.fits noise correction updated : file 214/224
# Pk1D-74_C.fits noise correction updated : file 215/224
# Pk1D-7_A.fits noise correction updated : file 216/224
# Pk1D-7_B.fits noise correction updated : file 217/224
# Pk1D-7_C.fits noise correction updated : file 218/224
# Pk1D-8_A.fits noise correction updated : file 219/224
# Pk1D-8_B.fits noise correction updated : file 220/224
# Pk1D-8_C.fits noise correction updated : file 221/224
# Pk1D-9_A.fits noise correction updated : file 222/224
# Pk1D-9_B.fits noise correction updated : file 223/224
# Pk1D-9_C.fits noise correction updated : file 224/224
# Done for all files(224)
